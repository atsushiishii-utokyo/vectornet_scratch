# %% [markdown]
# ## VectorNet implementation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1. Import libraries

# %%
from network.vectornet import *

# %% [markdown]
# ### 2. Instantiate the network

# %%
model = VectorNet()
